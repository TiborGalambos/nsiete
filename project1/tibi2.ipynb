# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

dfTrain = pd.read_csv('train.csv')
dfTest = pd.read_csv('test.csv')

# %% [markdown]
# # Train set description

# %%
dfTrain.describe()
# Out:
#        battery_power       blue  clock_speed     dual_sim           fc  \
# count    2000.000000  2000.0000  2000.000000  2000.000000  2000.000000
# mean     1238.518500     0.4950     1.522250     0.509500     4.309500
# std       439.418206     0.5001     0.816004     0.500035     4.341444
# min       501.000000     0.0000     0.500000     0.000000     0.000000
# 25%       851.750000     0.0000     0.700000     0.000000     1.000000
# 50%      1226.000000     0.0000     1.500000     1.000000     3.000000
# 75%      1615.250000     1.0000     2.200000     1.000000     7.000000
# max      1998.000000     1.0000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  ...  \
# count  2000.000000  2000.000000  2000.000000  2000.000000  2000.000000  ...
# mean      0.521500    32.046500     0.501750   140.249000     4.520500  ...
# std       0.499662    18.145715     0.288416    35.399655     2.287837  ...
# ...

# %%
dfTrain.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
dfTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
print(dfTrain.isnull().sum())
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
print(dfTrain.duplicated().any())
# Out:
# False

# %%
sns.countplot(x='price_range', data=dfTrain)
plt.show()

# %%
variances = np.var(dfTrain, axis=0)
print(variances)
# Out:
# battery_power    1.929918e+05
# blue             2.499750e-01
# clock_speed      6.655299e-01
# dual_sim         2.499098e-01
# fc               1.883871e+01
# four_g           2.495378e-01
# int_memory       3.291023e+02
# m_dep            8.314194e-02
# mobile_wt        1.252509e+03
# n_cores          5.231580e+00
# pc               3.675753e+01
# px_height        1.968429e+05
# px_width         1.867030e+05
# ram              1.176055e+06
# sc_h             1.774256e+01
# sc_w             1.896871e+01
# talk_time        2.983988e+01
# three_g          1.816178e-01
# touch_screen     2.499910e-01
# wifi             2.499510e-01
# price_range      1.250000e+00
# dtype: float64

# %%
plt.bar(dfTrain.columns, variances)
plt.xticks(rotation=90)
plt.xlabel('Features')
plt.ylabel('Variance')
plt.title('Variances of Mobile Price Classification Dataset')
plt.show()

# %%
fig, axs = plt.subplots(3, 7, figsize=(12, 8))
axs = axs.ravel()

for i, feature in enumerate(dfTrain.columns[:]):
    axs[i].boxplot(dfTrain[feature])
    axs[i].set_title(feature)

plt.tight_layout()
plt.show()

# %%
corr = dfTrain.corr()
plt.figure(figsize=(20,10))
sns.heatmap(corr, annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import MinMaxScaler

# Select features to normalize
features_to_normalize = ['battery_power', 'px_height', 'px_width', 'ram']

# Create MinMaxScaler object
scaler = MinMaxScaler()

# Normalize selected features
dfTrain[features_to_normalize] = scaler.fit_transform(dfTrain[features_to_normalize])

# %%
fig, axs = plt.subplots(3, 7, figsize=(12, 8))
axs = axs.ravel()

for i, feature in enumerate(dfTrain.columns[:]):
    axs[i].boxplot(dfTrain[feature])
    axs[i].set_title(feature)

plt.tight_layout()
plt.show()

# %%
from sklearn.model_selection import train_test_split

# Split the dataset into training and testing sets, stratifying on the target variable
X_train, X_validate, y_train, y_validate = train_test_split(dfTrain.drop('price_range', axis=1), dfTrain['price_range'], test_size=0.2, stratify=dfTrain['price_range'], random_state=42)

# Print the number of samples in each split
print(f'Train set size: {len(X_train)}, Validate set size: {len(X_test)}')
# Out:
# Train set size: 1600, Validate set size: 400

# %%
X_train.describe()
# Out:
#        battery_power         blue  clock_speed     dual_sim           fc  \
# count    1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean        0.491427     0.494375     1.529313     0.506875     4.322500
# std         0.292613     0.500125     0.817696     0.500109     4.337799
# min         0.000668     0.000000     0.500000     0.000000     0.000000
# 25%         0.232799     0.000000     0.700000     0.000000     1.000000
# 50%         0.481964     0.000000     1.500000     1.000000     3.000000
# 75%         0.743487     1.000000     2.225000     1.000000     7.000000
# max         1.000000     1.000000     3.000000     1.000000    19.000000
#
#             four_g   int_memory        m_dep    mobile_wt      n_cores  \
# count  1600.000000  1600.000000  1600.000000  1600.000000  1600.000000
# mean      0.518125    32.063125     0.503563   140.102500     4.546875
# std       0.499828    18.264382     0.289000    35.283567     2.286607
# ...

# %%
y_train.describe()
# Out:
# count    1600.000000
# mean        1.500000
# std         1.118384
# min         0.000000
# 25%         0.750000
# 50%         1.500000
# 75%         2.250000
# max         3.000000
# Name: price_range, dtype: float64

# %%
X_validate.describe()
# Out:
#        battery_power       blue  clock_speed    dual_sim          fc  \
# count     400.000000  400.00000     400.0000  400.000000  400.000000
# mean        0.497615    0.49750       1.4940    0.520000    4.257500
# std         0.297500    0.50062       0.8096    0.500226    4.361048
# min         0.000000    0.00000       0.5000    0.000000    0.000000
# 25%         0.240815    0.00000       0.6750    0.000000    0.000000
# 50%         0.500000    0.00000       1.4000    1.000000    3.000000
# 75%         0.747161    1.00000       2.2000    1.000000    7.000000
# max         0.998664    1.00000       3.0000    1.000000   18.000000
#
#            four_g  int_memory       m_dep  mobile_wt     n_cores          pc  \
# count  400.000000  400.000000  400.000000  400.00000  400.000000  400.000000
# mean     0.535000   31.980000    0.494500  140.83500    4.415000   10.085000
# std      0.499398   17.685348    0.286312   35.89888    2.292578    6.042272
# ...

# %%
y_validate.describe()
# Out:
# count    400.000000
# mean       1.500000
# std        1.119434
# min        0.000000
# 25%        0.750000
# 50%        1.500000
# 75%        2.250000
# max        3.000000
# Name: price_range, dtype: float64

# %% [markdown]
# # Test set description

# %%
dfTest.describe()
# Out:
#                 id  battery_power         blue  clock_speed     dual_sim  \
# count  1000.000000    1000.000000  1000.000000  1000.000000  1000.000000
# mean    500.500000    1248.510000     0.516000     1.540900     0.517000
# std     288.819436     432.458227     0.499994     0.829268     0.499961
# min       1.000000     500.000000     0.000000     0.500000     0.000000
# 25%     250.750000     895.000000     0.000000     0.700000     0.000000
# 50%     500.500000    1246.500000     1.000000     1.500000     1.000000
# 75%     750.250000    1629.250000     1.000000     2.300000     1.000000
# max    1000.000000    1999.000000     1.000000     3.000000     1.000000
#
#                 fc       four_g   int_memory        m_dep   mobile_wt  ...  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000  ...
# mean      4.593000     0.487000    33.652000     0.517500   139.51100  ...
# std       4.463325     0.500081    18.128694     0.280861    34.85155  ...
# ...

# %%
dfTest.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
dfTest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
print(dfTest.isnull().sum())
# Out:
# id               0
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# dtype: int64

# %% [markdown]
# # Vyhodnotenie

# %% [markdown]
# Zadanie budeme riešiť pomocou klasifikácie. Keďže úlohou je rozdelenie mobilov podľa odhadovanej ceny do 4 klás (0-3).

# %% [markdown]
# ### Tensorflow model

# %%
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
import sklearn

dataTrain = pd.read_csv('train.csv')

# Split the data into features and labels
XTrain = dataTrain.drop('price_range', axis=1)
yTrain = dataTrain['price_range']

#Convert the labels to categorical values
yTrain = tf.keras.utils.to_categorical(yTrain, num_classes=4)

from sklearn.preprocessing import MinMaxScaler
#Normalize XTest
def Normalize(XTrain):
    XTrain = (XTrain - XTrain.mean()) / XTrain.std()

def NormalizeSelectedFeaturesMinmax(XTrain):
    features_to_normalize = ['battery_power', 'px_height', 'px_width', 'ram']
    scaler = MinMaxScaler()
    XTrain[features_to_normalize] = scaler.fit_transform(XTrain[features_to_normalize])


def NormalizeAllFeaturesMinmax(XTrain):
    scaler = MinMaxScaler()
    XTrain = scaler.fit_transform(XTrain)


# Normalize data

Normalize(XTrain)
# NormalizeSelectedFeatures(XTrain)
NormalizeAllFeaturesMinmax(XTrain)
#Split data
XTrain, XTest, yTrain, yTest = train_test_split(XTrain, yTrain, test_size=0.2, random_state=42)

# %% [markdown]
# ### Pytorch model

# %%
import torch.nn as nn
import torch

# %%
# Set random seed
torch.manual_seed(42)

# %%
from torch.utils.data import Dataset, DataLoader, random_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np
# Define the MobilePriceDataset class
class MobilePriceDataset(Dataset):
    def __init__(self, csv_file):
        self.data = pd.read_csv(csv_file)
        self.X = self.data.drop(['price_range'], axis=1).values
        self.y = self.data['price_range'].values

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        X = torch.tensor(self.X[idx], dtype=torch.float32)
        y = torch.tensor(self.y[idx], dtype=torch.long)
        return X, y

# %%
import torch.nn as nn

class MobilePriceClassifier(nn.Module):
        def __init__(self, input_size, hidden_size, num_classes, num_layers):
            super(MobilePriceClassifier, self).__init__()
            self.fc1 = nn.Linear(input_size, hidden_size)
            self.relu = nn.ReLU()
            self.hidden_layers = nn.ModuleList()
            for i in range(num_layers):
                self.hidden_layers.append(nn.Linear(hidden_size, hidden_size))
            self.fc2 = nn.Linear(hidden_size, num_classes)

        def forward(self, x):
            print('aaa')
            out = self.fc1(x)
            out = self.relu(out)
            for layer in self.hidden_layers:
                out = layer(out)
                out = self.relu(out)
            out = self.fc2(out)
            m = nn.Softmax(dim=1)
            out = m(out)
            return out

# %%
import itertools
# Define the neural network model
import torch
import torch.nn as nn
import wandb

# Load the dataset
dataset = MobilePriceDataset('train.csv')
# Split the dataset into training and validation sets
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
# Define a range of hyperparameters to test
learning_rates = [0.01, 0.001]
batch_sizes = [8, 16,32]
hidden_sizes = [8, 16, 32]
num_layers = [2,4,8] #10, 15
normalizers = ['standard', 'minmax_all', 'minmax_selected']
highest_params = [0, 0, 0, 0]
highest_acc = 0

# Try all combinations of hyperparameters
for lr, batch_size, hidden_size, num_layers in itertools.product(learning_rates, batch_sizes, hidden_sizes, num_layers):
    print(f'learning rate: {lr}\n'
          f'batch_size: {batch_size}\n'
          f'hidden_size: {hidden_size}\n'
          f'num_layers: {num_layers}')
    wandb.init(project="tibi-merania")
    config = wandb.config
    config.learning_rate = lr
    config.batch_size = batch_size
    config.hidden_size = hidden_size
    config.num_layers = num_layers

    # Define the data loaders
    train_loader = DataLoader(train_dataset, batch_size)
    val_loader = DataLoader(val_dataset, batch_size)

    # Load the test dataset
    test_dataset = MobilePriceDataset('train.csv')

    # Define the data loader for the test set
    test_loader = DataLoader(test_dataset, batch_size)

    # Define the hyperparameters
    input_size = 20 # Number of input features
    num_classes = 4 # Number of output classes

    # Initialize the model
    model = MobilePriceClassifier(input_size, hidden_size, num_classes, num_layers)

    # Define the loss function and optimization algorithm
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr)

    # Train the model
    num_epochs = 20
    for epoch in range(num_epochs):
        for i, (inputs, labels) in enumerate(train_loader):
            # Forward pass
            outputs = model(inputs)
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Validate the model
        with torch.no_grad():
            correct = 0
            total = 0
            for inputs, labels in val_loader:
                outputs = model(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            accuracy = 100 * correct / total
            wandb.log({"epoch": epoch, "accuracy": accuracy, "loss": loss, "lr": lr, "batch_size": batch_size, "hidden_size": hidden_size, "num_layers": num_layers})
            print(f"Epoch {epoch+1}, validation accuracy: {accuracy:.2f}%")

    # Test the model
    with torch.no_grad():
        correct = 0
        total = 0
        for inputs, labels in test_loader:
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        accuracy = 100 * correct / total
        print(f"Test accuracy: {accuracy:.2f}%\n")
        if accuracy > highest_acc:
            highest_acc = accuracy
            highest_params = [lr,batch_size,hidden_size,num_layers]

print(f'\n\nhighest accuracy: {highest_acc}\n'
      f'learning rate: {highest_params[0]}\n'
      f'batch_size: {highest_params[1]}\n'
      f'hidden_size: {highest_params[2]}\n'
      f'num_layers: {highest_params[3]}')
wandb.finish()

# %%
import torch
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Load the data from the CSV file
data = pd.read_csv('train.csv')

# Split the data into training and validation sets
train_data, val_data = train_test_split(data, test_size=0.2)

# Define the neural network architecture
class Net(torch.nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(Net, self).__init__()
        self.fc1 = torch.nn.Linear(input_size, hidden_size)
        self.relu = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# Set the hyperparameters
input_size = 20 # number of features in the data
hidden_size = 10 # number of neurons in the hidden layer
num_classes = 4 # number of output classes
learning_rate = 0.001
num_epochs = 10

# Create the model, loss function, and optimizer
model = Net(input_size, hidden_size, num_classes)
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    for i, data in enumerate(train_data.values):
        # Separate the inputs and labels
        inputs, labels = data[:-1], data[-1]

        # Convert the inputs and labels to PyTorch tensors
        inputs = torch.from_numpy(inputs).float()
        labels = torch.tensor(int(labels)).long()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs.unsqueeze(0), labels.unsqueeze(0))

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Print the loss for every 1000th iteration
        if (i+1) % 1000 == 0:
            print('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}'
                  .format(epoch+1, num_epochs, i+1, len(train_data), loss.item()))

# Evaluate the model on the validation set
with torch.no_grad():
    correct = 0
    total = 0
    for batch in val_data:
        # Unpack the batch
        inputs, labels, *_ = batch

        # Convert the inputs and labels to PyTorch tensors
        inputs = torch.from_numpy(inputs.values).float().to(device)
        labels = torch.from_numpy(labels.values).long().to(device)

        # Forward pass
        outputs = model(inputs)
        _, predicted = torch.max(outputs.data, 1)

        # Compute the accuracy
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Accuracy of the model on the validation set: {} %'.format(100 * correct / total))
# Out:
# Epoch [1/10], Step [1000/1600], Loss: 12.8231
# Epoch [2/10], Step [1000/1600], Loss: 0.5670
# Epoch [3/10], Step [1000/1600], Loss: 0.2774
# Epoch [4/10], Step [1000/1600], Loss: 0.0480
# Epoch [5/10], Step [1000/1600], Loss: 0.3252
# Epoch [6/10], Step [1000/1600], Loss: 0.2254
# Epoch [7/10], Step [1000/1600], Loss: 1.2077
# Epoch [8/10], Step [1000/1600], Loss: 2.5100
# Epoch [9/10], Step [1000/1600], Loss: 0.1457
# Epoch [10/10], Step [1000/1600], Loss: 0.5381
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[123], line 71
#      68 inputs, labels, *_ = batch
#      70 # Convert the inputs and labels to PyTorch tensors
# ---> 71 inputs = torch.from_numpy(inputs.values).float().to(device)
#      72 labels = torch.from_numpy(labels.values).long().to(device)
#      74 # Forward pass
#
# AttributeError: 'str' object has no attribute 'values'
